# %% [markdown]
# ### User inputs
# ### Statements: Control Structures ( Branching, condtional and iteration)

# %% [markdown]
# ## User Inputs

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q = 459
p = 0.098

# Sample print statement
print(q, p, p * q)
print(q, p, p * q, sep=",")
print(q, p, p * q, sep=" :- ")
print(str(q) + " " + str(p) + " " + str(p * q))
# Out:
# 459 0.098 44.982
# 459,0.098,44.982
# 459 :- 0.098 :- 44.982
# 459 0.098 44.982

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Syntax                                     %[flags][width][.precision]type

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Conversion details
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  The alternate method of formatting the output contents is as follows
# #### .format()
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## input() to accept user input

# %%
x1=input()
# Out:
# a

# %%
# Default type of all inputs is string

print(type(x1))

# Example : Type casting to int 

y=int(int(input('Enter a number : ')))

print(y,type(y),sep='\n')
# Out:
# <class 'str'>
# Enter a number : 12
# 12
# <class 'int'>
